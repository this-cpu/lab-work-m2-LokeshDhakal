# %%
import cv2
import matplotlib.pyplot as plt

# Read image
image = cv2.imread("image/images.jpg")

# Convert BGR to RGB for correct display
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display image
plt.imshow(image_rgb)
plt.title("Original Image")
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import cv2
#       2 import matplotlib.pyplot as plt
#       4 # Read image
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import numpy as np

# Print image properties
print("Image Shape (Height, Width, Channels):", images.shape)
print("Image Data Type:", image.dtype)

# Display pixel value at a specific location
x, y = 100, 100
print(f"Pixel value at ({x},{y}):", image[x, y])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 import numpy as np
#       3 # Print image properties
# ----> 4 print("Image Shape (Height, Width, Channels):", images.shape)
#       5 print("Image Data Type:", image.dtype)
#       7 # Display pixel value at a specific location
#
# NameError: name 'images' is not defined
